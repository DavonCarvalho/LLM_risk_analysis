# %%
import pandas as pd
import numpy as np

data=pd.read_excel("actioncountsFinance.xlsx")
# Assuming 'data' is your DataFrame after loading from the Excel file
# Replace 'month_year' and 'count_of_attacks' with the actual column names from your data
# 'month_year' = data['month_year_column_name']
# 'count_of_attacks' = data['count_of_attacks_column_name']

# First, define the state mapping
def map_count_to_state(count):
    if count == 0:
        return 0
    elif 1 <= count <= 5:
        return 1
    elif 6 <= count <= 10:
        return 2
    else:
        return 3

# Apply the mapping function to your attack counts
data['state'] = data['total_attacks'].apply(map_count_to_state)

# Create an empty transition matrix based on the number of states
num_states = data['state'].max() + 1
transition_matrix = np.zeros((num_states, num_states))

# Count the transitions
for i in range(len(data) - 1):
    current_state = data['state'].iloc[i]
    next_state = data['state'].iloc[i + 1]
    transition_matrix[current_state][next_state] += 1

# Normalize the counts to probabilities
for i in range(num_states):
    total = np.sum(transition_matrix[i])
    if total > 0:
        transition_matrix[i] /= total

# Output the transition matrix
transition_matrix_df = pd.DataFrame(transition_matrix)
print(transition_matrix_df)
# Out:
#           0         1         2         3
# 0  0.100000  0.600000  0.200000  0.100000
# 1  0.083333  0.458333  0.250000  0.208333
# 2  0.076923  0.307692  0.205128  0.410256
# 3  0.030769  0.123077  0.261538  0.584615

# %%
0data.head()
# Out:
#      date  total_attacks
# 0  0-1995              4
# 1  0-2002              1
# 2  0-2005             17
# 3  0-2006             14
# 4  0-2007              6

# %%
data.drop(index=1,inplace=True)

# %%
data
# Out:
# 1     Row Labels Sum of count_of_attacks
# 2       1.0-2006                       1
# 3       1.0-2008                       2
# 4       1.0-2009                       1
# 5       1.0-2010                       2
# 6       1.0-2011                      14
# ..           ...                     ...
# 184     nan-2019                      17
# 185     nan-2020                       8
# 186     nan-2021                       3
# 187      (blank)                     NaN
# 188  Grand Total                    2449
#
# [187 rows x 2 columns]
